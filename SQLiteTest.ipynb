# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlite3

import pandas as pd

import numpy

# %%
# Create an engine for the chinook.sqlite database
conn = sqlite3.connect('database.sqlite')

df = pd.read_sql_query("SELECT * FROM loan",conn)

#df = pd.read_sql_query("SELECT *,case when loan_status in ('Fully Paid', 'Current', 'In Grace Period', None, 'Does not meet the credit policy. Status:Fully Paid', 'Issued') then 'Good' WHEN loan_status not in ('Fully Paid', 'Current', 'In Grace Period', None, 'Does not meet the credit policy. Status:Fully Paid', 'Issued') then 'Bad' end as 'New_Loan_Status' from loan", conn)

# %%
df['year'] = df['issue_d'].astype('datetime64[ns]').dt.year

df_new = df.loc[df['year'] < 2014.0]

df_new.to_csv("loan_2013.csv")

# %%
df_new = df.loc[df['year'] < 2014.0]

# %%
# del df_new ['column_name']

df_new
# Out:
#          index       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0            0  1077501  1296599.0     5000.0       5000.0           4975.0
# 1            1  1077430  1314167.0     2500.0       2500.0           2500.0
# 2            2  1077175  1313524.0     2400.0       2400.0           2400.0
# 3            3  1076863  1277178.0    10000.0      10000.0          10000.0
# 4            4  1075358  1311748.0     3000.0       3000.0           3000.0
# ...        ...      ...        ...        ...          ...              ...
# 230654  188118  1062400  1294262.0    20500.0      20500.0          20500.0
# 230655  188119  1059394  1291010.0    15000.0      15000.0          15000.0
# 230656  188120  1059224  1290827.0    35000.0      35000.0          35000.0
# 230657  188121  1058722  1290521.0    12000.0      12000.0          12000.0
# 230658  188122  1058291  1289878.0    12000.0       7775.0           7775.0
#
#               term int_rate  installment grade  ... il_util open_rv_12m  \
# 0        36 months   10.65%       162.87     B  ...     NaN         NaN
# 1        60 months   15.27%        59.83     C  ...     NaN         NaN
# 2        36 months   15.96%        84.33     C  ...     NaN         NaN
# 3        36 months   13.49%       339.31     C  ...     NaN         NaN
# 4        60 months   12.69%        67.79     B  ...     NaN         NaN
# ...            ...      ...          ...   ...  ...     ...         ...
# 230654   36 months   16.77%       728.54     D  ...     NaN         NaN
# 230655   36 months   15.27%       521.97     C  ...     NaN         NaN
# 230656   36 months   15.96%      1229.81     C  ...     NaN         NaN
# 230657   36 months   16.29%       423.61     D  ...     NaN         NaN
# 230658   60 months   15.27%       186.08     C  ...     NaN         NaN
#
#        open_rv_24m max_bal_bc  all_util total_rev_hi_lim inq_fi total_cu_tl  \
# 0              NaN        NaN       NaN              NaN    NaN         NaN
# 1              NaN        NaN       NaN              NaN    NaN         NaN
# 2              NaN        NaN       NaN              NaN    NaN         NaN
# 3              NaN        NaN       NaN              NaN    NaN         NaN
# 4              NaN        NaN       NaN              NaN    NaN         NaN
# ...            ...        ...       ...              ...    ...         ...
# 230654         NaN        NaN       NaN              NaN    NaN         NaN
# 230655         NaN        NaN       NaN              NaN    NaN         NaN
# 230656         NaN        NaN       NaN              NaN    NaN         NaN
# 230657         NaN        NaN       NaN              NaN    NaN         NaN
# 230658         NaN        NaN       NaN              NaN    NaN         NaN
#
#        inq_last_12m    year
# 0               NaN  2011.0
# 1               NaN  2011.0
# 2               NaN  2011.0
# 3               NaN  2011.0
# 4               NaN  2011.0
# ...             ...     ...
# 230654          NaN  2012.0
# 230655          NaN  2012.0
# 230656          NaN  2012.0
# 230657          NaN  2012.0
# 230658          NaN  2012.0
#
# [230658 rows x 76 columns]

# %%
loan_status_unq = df_new["loan_status"].unique()

loan_status_unq
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
a = [0,2,5,7]
b = [1,3,4,6,8]

bad_Loan = [loan_status_unq[i] for i in b]

good_Loan = [loan_status_unq[i] for i in a]

bad_Loan

good_Loan
# Out:
# ['Fully Paid',
#  'Current',
#  'In Grace Period',
#  'Does not meet the credit policy. Status:Fully Paid']

# %%
z = 0

df_new["new_loan_status"] = []

for x in df_new["loan_status"]:
    if x in bad_Loan:
        df_new["new_loan_status"][z] = "bad"
    elif x in good_Loan:
        df_new["new_loan_status"][z] = "good"
    z+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-c8efe3b20b4a> in <module>
#       1 z = 0
#       2
# ----> 3 df_new["new_loan_status"] = []
#       4
#       5 for x in df_new["loan_status"]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
